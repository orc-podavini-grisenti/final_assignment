# %% [markdown]
# ### Cell 0: ( Only for Colab ) Install the git **repository**

# %%
import sys
import os

# 1. Clone the repository
# !git clone -b trajectory_tracking_policy https://github.com/orc-podavini-grisenti/final_assignment

# 2. Point the project_root specifically to the cloned folder
# In Colab, the folder structure will be /content/final_assignment/
project_root = os.path.abspath('/content/final_assignment')

# 3. Add that specific folder to the system path
if project_root not in sys.path:
    sys.path.append(project_root)


# 4. Link the Drive to the colab in order to store the results
from google.colab import drive
drive.mount('/content/drive')

drive_path = "/content/drive/MyDrive/final_assignment/outputs/models_saved"

# Crea la cartella se non esiste
if not os.path.exists(drive_path):
    os.makedirs(drive_path)
# Out:
# fatal: destination path 'final_assignment' already exists and is not an empty directory.
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Cell 1: Imports & Setup

# %%
import sys
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.distributions import Normal
import numpy as np
import matplotlib.pyplot as plt

# --- PATH SETUP ---
# Add the project root to sys.path so we can import envs/planner
# Adjust '..' depending on where this notebook is located relative to root
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)

from envs.unicycle_env import UnicycleEnv
from planner.dubins_planner import DubinsPlanner
from models.trajectory_tracking_network import TTNetwork
from utils.normalization import ObservationNormalizer

# Check if CUDA is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Running on: {device}")
# Out:
# Running on: cuda

# %% [markdown]
# ### Cell 2: Load Training Hyperparameters

# %%
# Hyperparameters
MAX_EPISODES = 2000
MAX_STEPS    = 200
LR           = 3e-4
BATCH_SIZE   = 20
GAMMA        = 0.99

SAVE_ON_DRIVE = True

# %% [markdown]
# ### Cell 3: Intialization

# %%
# Init Enviroment and Dubins Planner
env = UnicycleEnv()

# Initilize the Network.
obs_dim = 3     # Obs dim is 3 (rho, alpha, d_theta)
action_dim = 2  # v, omega

policy = TTNetwork(obs_dim, action_dim).to(device)

# Initializa the otpimizar
optimizer = optim.Adam(policy.parameters(), lr=LR)

# --- Scheduler ---
# Reduces LR by factor of 0.5 every 200 episodes
# This helps the network "settle" into the precise solution
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=200, gamma=0.5)

# Initializa the input normalizer
obs_normalizer = ObservationNormalizer(max_dist=3.0)

gamma = GAMMA

# Memory buffer for the current episode
log_probs = []
rewards = []

# Memory buffer fot the current batch
loss_history = [] # Store all the batch losses

# %% [markdown]
# ### Cell 4: Helpers

# %%
def get_action(obs):
    """Samples an action and stores its log_probability."""
    # Use the imported normalizer to normaliza the inputs features to give the same relevance
    norm_obs = obs_normalizer.normalize_tt(obs)

    obs_t = torch.FloatTensor(norm_obs).unsqueeze(0).to(device)

    # Call the network to get a action distribution
    mean, std = policy(obs_t)
    dist = Normal(mean, std)

    # Sample a randome action from this distribution
    # NB: randomcicity ensure exploration
    action = dist.sample()

    # Store log_prob for the update step later
    # Sum over action dimensions (v and omega)
    log_prob = dist.log_prob(action).sum(dim=1)
    log_probs.append(log_prob)

    # Return numpy action for the environment
    # Clip to ensure physical validity [-1, 1]
    return np.clip(action.cpu().detach().numpy()[0], -1.0, 1.0)


def store_reward(reward):
    rewards.append(reward)

def store_batch_loss(loss):
    loss_history.append(loss)

def sample_radius(mean=1.65, std=0.3, min_r=1, max_r=2.5, size=1):
    """
    Samples a radius using a Gaussian distribution, strictly constrained.
    """
    # 1. Sample from the normal distribution
    samples = np.random.normal(loc=mean, scale=std, size=size)

    # 2. Hard constrain using clipping
    constrained_samples = np.clip(samples, min_r, max_r)

    return constrained_samples[0] if size == 1 else constrained_samples

# %% [markdown]
# ### Cell 5: Reinforce Update

# %%
# Global storage for the whole batch of trajectories
batch_log_probs = []
batch_returns = []

def calculate_discounted_returns():
    """
    Calculates the 'Return-to-Go' (G_t) for the current episode using causality.

    Mathematical Concept:
    Instead of using the total reward C(tau) for every step, we use G_t:
    G_t = sum_{k=t}^H gamma^(k-t) * r_k

    This reduces variance because actions at time 't' are only reinforced
    based on rewards that happen *after* time 't' (Causality).
    """
    global log_probs, rewards, batch_log_probs, batch_returns

    G_t = 0
    returns = []

    # 1. Calculate Discounted Returns (Backwards)
    # We iterate backwards to easily compute G_t = r_t + gamma * G_{t+1}
    for r in reversed(rewards):
        G_t = r + gamma * G_t
        returns.insert(0, G_t)

    # 2. Store for the Batch Update
    # We do NOT normalize here. We wait to collect all episodes in the batch
    # so we can normalize across the entire dataset (Batch-wise normalization).
    batch_log_probs.extend(log_probs)
    batch_returns.extend(returns)

    # Clear episode memory
    log_probs = []
    rewards = []

def update():
    """
    Performs the Policy Gradient Update using the REINFORCE algorithm.

    Equation Implemented:
    ∇J ≈ (1/N) * Σ_i Σ_t [ ∇ log π(u_t|x_t) * G_t ]

    Where:
    - (1/N): Averaging over the batch size (len(batch_returns))
    - Σ_t: Summing over time steps (done via torch.sum or iterative addition)
    - ∇ log π: Gradients calculated via loss.backward() on log_probs
    - G_t: The normalized returns-to-go
    """
    global batch_log_probs, batch_returns, optimizer

    # Security check: if batch is empty, skip
    if len(batch_returns) == 0:
        return

    # 1. Prepare Data
    # Convert list of returns to a Tensor
    returns_t = torch.tensor(batch_returns).float().to(device)

    # 2. Batch-Wise Normalization (Crucial for Stability)
    # This aligns the returns to be roughly N(0, 1), stabilizing the gradients.
    # It acts as a baseline: actions with G_t > mean are encouraged (+),
    # actions with G_t < mean are discouraged (-).
    if len(returns_t) > 1:
        returns_t = (returns_t - returns_t.mean()) / (returns_t.std() + 1e-9)

    # 3. Calculate Policy Loss
    # We want to maximize J, so we minimize Loss = -J
    # Loss = - Σ ( log_prob * G_t )
    policy_loss = []
    for log_prob, G_t in zip(batch_log_probs, returns_t):
        # Term: - log π(u_t|x_t) * G_t
        policy_loss.append(-log_prob * G_t)

    # Summing all terms corresponds to the Σ_i Σ_t part of the equation
    loss = torch.stack(policy_loss).sum()

    # 4. Backpropagation
    # Dividing by the number of episodes corresponds to the (1/N) term
    # This keeps the gradient magnitude consistent regardless of batch size.
    loss = loss / BATCH_SIZE

    optimizer.zero_grad()
    loss.backward()  # This computes ∇_theta

    # Gradient Clipping (Optional but recommended to prevent exploding gradients)
    torch.nn.utils.clip_grad_norm_(policy.parameters(), 1.0)

    optimizer.step() # Update parameters theta

    # 5. Logging and Cleanup
    store_batch_loss(loss.item())

    # Clear batch memory for the next set of episodes
    batch_log_probs = []
    batch_returns = []

# %% [markdown]
# ### Cell 6: Training

# %%
# --- Scaled Rewards ---
REWARD_GOAL = 200.0
REWARD_COLLISION = -200.0
REWARD_OFF_PATH = -200.0
REWARD_MAX_STEPS = -100.0
REWARD_CHECKPOINT = 10.0  # Per point cleared
PENALTY_STEP_ERROR = -0.1 # Per meter of error

reward_history = []

print("Starting Training...")

for episode in range(MAX_EPISODES):
    obs, info = env.reset()

    start_pose = env.state
    goal_pose = env.goal
    random_radius = sample_radius()
    planner = DubinsPlanner(curvature_max=random_radius, step_size=0.2)
    path = planner.get_path(start_pose, goal_pose)
    if path is None: continue

    path_idx = 0
    ep_reward = 0
    episode_errors = []
    breack_reason = "Max step reached"

    for t in range(MAX_STEPS):
        old_idx = path_idx
        tracking_obs = obs[:3]
        action = get_action(tracking_obs)

        # 1. Environment Step
        obs, env_reward, terminated, truncated, info = env.step(action)

        # 2. Update Path Tracking Logic
        path_xy = path[:, :2]
        dists = np.linalg.norm(path_xy - env.state[:2], axis=1)
        current_tracking_error = np.min(dists)
        episode_errors.append(current_tracking_error)

        closest_idx = np.argmin(dists)
        lookahead_idx = closest_idx + 1
        if lookahead_idx > path_idx and lookahead_idx < len(path):
            path_idx = lookahead_idx

        # 3. Calculate Shaped Reward
        # Determine if we made progress this step
        path_idx_increased = (path_idx > old_idx)

        # Dense reward for staying close to current sequential target
        step_reward = PENALTY_STEP_ERROR * current_tracking_error

        if path_idx_increased:
            # Small "breadcrumb" reward for hitting checkpoints
            num_points_cleared = path_idx - old_idx
            step_reward += REWARD_CHECKPOINT * num_points_cleared

        # 4. Override with terminal rewards if necessary
        dist_to_final = np.linalg.norm(env.state[:2] - goal_pose[:2])
        is_success = dist_to_final < 0.1 and path_idx >= len(path) - 2

        if is_success:
            step_reward += REWARD_GOAL
            terminated = True
            breack_reason = "Goal Reached"
        elif info['collision']:
            step_reward += REWARD_COLLISION
            terminated = True
            breack_reason = "Collision"
        elif current_tracking_error > 2.0:
            step_reward += REWARD_OFF_PATH
            terminated = True
            breack_reason = "Too Far from Path"

        # 5. Store and Accumulate
        store_reward(step_reward)
        ep_reward += step_reward

        if terminated or truncated:
            break

    if breack_reason == "Max step reached":
        ep_reward += REWARD_MAX_STEPS

    # Update logic (discounting, logging, etc.)
    calculate_discounted_returns()
    avg_error = np.mean(episode_errors)
    # ... rest of your update/log code ...

    # 4. If we have collected 'm' trajectories, perform the update
    if (episode + 1) % BATCH_SIZE == 0:
        update() # This effectively divides by m
        print(f"Update performed at episode {episode}")

    reward_history.append(ep_reward)

    if (episode + 1) % BATCH_SIZE == 0:
        avg_r = np.mean(reward_history[-20:])
        print(f"Episode {episode} | Avg Reward: {avg_r:.1f} | Avg Error: {avg_error:.4f}m | Path Len: {len(path)}, Path Step Reached: {path_idx}, {breack_reason}")

print("Training Complete.")
# Out:
# Starting Training...
# Update performed at episode 19
# Episode 19 | Avg Reward: -73.6 | Avg Error: 0.7593m | Path Len: 15, Path Step Reached: 14, Too Far from Path
# Update performed at episode 39
# Episode 39 | Avg Reward: -57.4 | Avg Error: 0.7559m | Path Len: 8, Path Step Reached: 7, Too Far from Path
# Update performed at episode 59
# Episode 59 | Avg Reward: -9.0 | Avg Error: 0.7605m | Path Len: 16, Path Step Reached: 15, Too Far from Path
# Update performed at episode 79
# Episode 79 | Avg Reward: -36.1 | Avg Error: 0.8680m | Path Len: 23, Path Step Reached: 5, Too Far from Path
# Update performed at episode 99
# Episode 99 | Avg Reward: -64.5 | Avg Error: 0.7669m | Path Len: 12, Path Step Reached: 11, Too Far from Path
# Update performed at episode 119
# Episode 119 | Avg Reward: -25.3 | Avg Error: 0.4321m | Path Len: 26, Path Step Reached: 25, Max step reached
# Update performed at episode 139
# Episode 139 | Avg Reward: -51.1 | Avg Error: 0.9988m | Path Len: 15, Path Step Reached: 7, Too Far from Path
# Update performed at episode 159
# Episode 159 | Avg Reward: 0.4 | Avg Error: 0.4028m | Path Len: 23, Path Step Reached: 17, Max step reached
# Update performed at episode 179
# Episode 179 | Avg Reward: -32.9 | Avg Error: 0.8562m | Path Len: 27, Path Step Reached: 26, Max step reached
# Update performed at episode 199
# Episode 199 | Avg Reward: -25.6 | Avg Error: 0.4971m | Path Len: 17, Path Step Reached: 16, Max step reached
# Update performed at episode 219
# Episode 219 | Avg Reward: 39.4 | Avg Error: 0.6874m | Path Len: 20, Path Step Reached: 13, Too Far from Path
# Update performed at episode 239
# Episode 239 | Avg Reward: -23.9 | Avg Error: 0.4308m | Path Len: 24, Path Step Reached: 23, Max step reached
# Update performed at episode 259
# Episode 259 | Avg Reward: -51.8 | Avg Error: 0.6174m | Path Len: 18, Path Step Reached: 17, Too Far from Path
# Update performed at episode 279
# Episode 279 | Avg Reward: -57.0 | Avg Error: 0.7971m | Path Len: 17, Path Step Reached: 15, Too Far from Path
# Update performed at episode 299
# Episode 299 | Avg Reward: 54.2 | Avg Error: 1.0482m | Path Len: 25, Path Step Reached: 4, Too Far from Path
# Update performed at episode 319
# Episode 319 | Avg Reward: -21.5 | Avg Error: 0.6770m | Path Len: 18, Path Step Reached: 13, Too Far from Path
# Update performed at episode 339
# Episode 339 | Avg Reward: 23.4 | Avg Error: 0.6485m | Path Len: 19, Path Step Reached: 10, Max step reached
# Update performed at episode 359
# Episode 359 | Avg Reward: -50.4 | Avg Error: 0.6383m | Path Len: 9, Path Step Reached: 8, Too Far from Path
# Update performed at episode 379
# Episode 379 | Avg Reward: 7.7 | Avg Error: 0.9127m | Path Len: 18, Path Step Reached: 17, Max step reached
# Update performed at episode 399
# Episode 399 | Avg Reward: -7.7 | Avg Error: 0.3047m | Path Len: 18, Path Step Reached: 17, Max step reached
# Update performed at episode 419
# Episode 419 | Avg Reward: 8.1 | Avg Error: 0.8537m | Path Len: 13, Path Step Reached: 9, Too Far from Path
# Update performed at episode 439
# Episode 439 | Avg Reward: -19.5 | Avg Error: 0.5722m | Path Len: 29, Path Step Reached: 28, Max step reached
# Update performed at episode 459
# Episode 459 | Avg Reward: 35.6 | Avg Error: 0.5439m | Path Len: 14, Path Step Reached: 10, Max step reached
# Update performed at episode 479
# Episode 479 | Avg Reward: -16.9 | Avg Error: 0.9311m | Path Len: 29, Path Step Reached: 5, Too Far from Path
# Update performed at episode 499
# Episode 499 | Avg Reward: 23.6 | Avg Error: 0.2571m | Path Len: 20, Path Step Reached: 7, Max step reached
# Update performed at episode 519
# Episode 519 | Avg Reward: 30.0 | Avg Error: 0.6720m | Path Len: 13, Path Step Reached: 12, Max step reached
# Update performed at episode 539
# Episode 539 | Avg Reward: 52.8 | Avg Error: 0.7722m | Path Len: 10, Path Step Reached: 9, Max step reached
# Update performed at episode 559
# Episode 559 | Avg Reward: 34.1 | Avg Error: 0.2722m | Path Len: 17, Path Step Reached: 15, Max step reached
# Update performed at episode 579
# Episode 579 | Avg Reward: 44.9 | Avg Error: 0.5733m | Path Len: 16, Path Step Reached: 13, Max step reached
# Update performed at episode 599
# Episode 599 | Avg Reward: 14.8 | Avg Error: 0.4880m | Path Len: 13, Path Step Reached: 12, Max step reached
# Update performed at episode 619
# Episode 619 | Avg Reward: 77.3 | Avg Error: 0.4931m | Path Len: 15, Path Step Reached: 12, Max step reached
# Update performed at episode 639
# Episode 639 | Avg Reward: 7.0 | Avg Error: 0.3075m | Path Len: 15, Path Step Reached: 14, Max step reached
# Update performed at episode 659
# Episode 659 | Avg Reward: 11.2 | Avg Error: 0.5069m | Path Len: 19, Path Step Reached: 16, Max step reached
# Update performed at episode 679
# Episode 679 | Avg Reward: 58.8 | Avg Error: 0.6137m | Path Len: 11, Path Step Reached: 10, Too Far from Path
# Update performed at episode 699
# Episode 699 | Avg Reward: 26.3 | Avg Error: 0.5931m | Path Len: 13, Path Step Reached: 12, Max step reached
# Update performed at episode 719
# Episode 719 | Avg Reward: 53.0 | Avg Error: 0.2936m | Path Len: 19, Path Step Reached: 14, Max step reached
# Update performed at episode 739
# Episode 739 | Avg Reward: 12.0 | Avg Error: 0.2248m | Path Len: 17, Path Step Reached: 15, Max step reached
# Update performed at episode 759
# Episode 759 | Avg Reward: 71.1 | Avg Error: 0.2025m | Path Len: 30, Path Step Reached: 8, Max step reached
# Update performed at episode 779
# Episode 779 | Avg Reward: 28.0 | Avg Error: 0.3071m | Path Len: 18, Path Step Reached: 16, Max step reached
# Update performed at episode 799
# Episode 799 | Avg Reward: 33.6 | Avg Error: 0.9315m | Path Len: 15, Path Step Reached: 6, Too Far from Path
# Update performed at episode 819
# Episode 819 | Avg Reward: 86.0 | Avg Error: 0.0905m | Path Len: 12, Path Step Reached: 11, Goal Reached
# Update performed at episode 839
# Episode 839 | Avg Reward: 53.9 | Avg Error: 1.0925m | Path Len: 19, Path Step Reached: 7, Max step reached
# Update performed at episode 859
# Episode 859 | Avg Reward: 44.3 | Avg Error: 0.9061m | Path Len: 19, Path Step Reached: 18, Max step reached
# Update performed at episode 879
# Episode 879 | Avg Reward: 36.9 | Avg Error: 0.6434m | Path Len: 12, Path Step Reached: 9, Max step reached
# Update performed at episode 899
# Episode 899 | Avg Reward: 40.6 | Avg Error: 0.6989m | Path Len: 23, Path Step Reached: 22, Too Far from Path
# Update performed at episode 919
# Episode 919 | Avg Reward: 41.2 | Avg Error: 0.9137m | Path Len: 10, Path Step Reached: 8, Max step reached
# Update performed at episode 939
# Episode 939 | Avg Reward: 68.5 | Avg Error: 0.3973m | Path Len: 16, Path Step Reached: 15, Max step reached
# Update performed at episode 959
# Episode 959 | Avg Reward: 34.0 | Avg Error: 0.3343m | Path Len: 19, Path Step Reached: 5, Max step reached
# Update performed at episode 979
# Episode 979 | Avg Reward: 46.1 | Avg Error: 0.3352m | Path Len: 21, Path Step Reached: 20, Max step reached
# Update performed at episode 999
# Episode 999 | Avg Reward: 57.9 | Avg Error: 0.4799m | Path Len: 13, Path Step Reached: 12, Max step reached
# Update performed at episode 1019
# Episode 1019 | Avg Reward: 36.6 | Avg Error: 0.5543m | Path Len: 11, Path Step Reached: 10, Max step reached
# Update performed at episode 1039
# Episode 1039 | Avg Reward: 49.3 | Avg Error: 0.5722m | Path Len: 11, Path Step Reached: 10, Max step reached
# Update performed at episode 1059
# Episode 1059 | Avg Reward: 47.0 | Avg Error: 0.1654m | Path Len: 20, Path Step Reached: 5, Max step reached
# Update performed at episode 1079
# Episode 1079 | Avg Reward: 71.3 | Avg Error: 0.1757m | Path Len: 23, Path Step Reached: 18, Max step reached
# Update performed at episode 1099
# Episode 1099 | Avg Reward: 88.2 | Avg Error: 0.6328m | Path Len: 16, Path Step Reached: 15, Max step reached
# Update performed at episode 1119
# Episode 1119 | Avg Reward: 31.0 | Avg Error: 0.1723m | Path Len: 25, Path Step Reached: 20, Max step reached
# Update performed at episode 1139
# Episode 1139 | Avg Reward: 32.8 | Avg Error: 0.5919m | Path Len: 14, Path Step Reached: 13, Max step reached
# Update performed at episode 1159
# Episode 1159 | Avg Reward: 58.6 | Avg Error: 0.2324m | Path Len: 18, Path Step Reached: 17, Max step reached
# Update performed at episode 1179
# Episode 1179 | Avg Reward: 85.7 | Avg Error: 0.4946m | Path Len: 14, Path Step Reached: 13, Max step reached
# Update performed at episode 1199
# Episode 1199 | Avg Reward: 63.8 | Avg Error: 0.4659m | Path Len: 19, Path Step Reached: 9, Max step reached
# Update performed at episode 1219
# Episode 1219 | Avg Reward: 38.9 | Avg Error: 0.0696m | Path Len: 11, Path Step Reached: 10, Goal Reached
# Update performed at episode 1239
# Episode 1239 | Avg Reward: 88.8 | Avg Error: 0.8302m | Path Len: 10, Path Step Reached: 9, Max step reached
# Update performed at episode 1259
# Episode 1259 | Avg Reward: 95.7 | Avg Error: 0.4269m | Path Len: 19, Path Step Reached: 18, Max step reached
# Update performed at episode 1279
# Episode 1279 | Avg Reward: 76.0 | Avg Error: 0.6552m | Path Len: 36, Path Step Reached: 35, Max step reached
# Update performed at episode 1299
# Episode 1299 | Avg Reward: 98.1 | Avg Error: 0.2038m | Path Len: 29, Path Step Reached: 28, Max step reached
# Update performed at episode 1319
# Episode 1319 | Avg Reward: 45.4 | Avg Error: 0.2941m | Path Len: 26, Path Step Reached: 25, Max step reached
# Update performed at episode 1339
# Episode 1339 | Avg Reward: 105.0 | Avg Error: 0.4126m | Path Len: 14, Path Step Reached: 13, Max step reached
# Update performed at episode 1359
# Episode 1359 | Avg Reward: 118.4 | Avg Error: 0.1979m | Path Len: 21, Path Step Reached: 20, Max step reached
# Update performed at episode 1379
# Episode 1379 | Avg Reward: 47.4 | Avg Error: 0.5305m | Path Len: 18, Path Step Reached: 17, Max step reached
# Update performed at episode 1399
# Episode 1399 | Avg Reward: 88.2 | Avg Error: 0.3150m | Path Len: 24, Path Step Reached: 23, Max step reached
# Update performed at episode 1419
# Episode 1419 | Avg Reward: 84.2 | Avg Error: 0.3617m | Path Len: 18, Path Step Reached: 17, Max step reached
# Update performed at episode 1439
# Episode 1439 | Avg Reward: 73.7 | Avg Error: 0.3368m | Path Len: 17, Path Step Reached: 16, Max step reached
# Update performed at episode 1459
# Episode 1459 | Avg Reward: 88.2 | Avg Error: 0.0420m | Path Len: 9, Path Step Reached: 8, Goal Reached
# Update performed at episode 1479
# Episode 1479 | Avg Reward: 40.0 | Avg Error: 0.2923m | Path Len: 18, Path Step Reached: 17, Max step reached
# Update performed at episode 1499
# Episode 1499 | Avg Reward: 85.5 | Avg Error: 0.3745m | Path Len: 25, Path Step Reached: 24, Max step reached
# Update performed at episode 1519
# Episode 1519 | Avg Reward: 97.4 | Avg Error: 0.5076m | Path Len: 21, Path Step Reached: 20, Max step reached
# Update performed at episode 1539
# Episode 1539 | Avg Reward: 51.0 | Avg Error: 0.5039m | Path Len: 17, Path Step Reached: 16, Max step reached
# Update performed at episode 1559
# Episode 1559 | Avg Reward: 109.8 | Avg Error: 0.5246m | Path Len: 13, Path Step Reached: 12, Max step reached
# Update performed at episode 1579
# Episode 1579 | Avg Reward: 86.6 | Avg Error: 0.6852m | Path Len: 26, Path Step Reached: 25, Max step reached
# Update performed at episode 1599
# Episode 1599 | Avg Reward: 95.7 | Avg Error: 0.7002m | Path Len: 15, Path Step Reached: 14, Max step reached
# Update performed at episode 1619
# Episode 1619 | Avg Reward: 73.7 | Avg Error: 0.0493m | Path Len: 10, Path Step Reached: 9, Goal Reached
# Update performed at episode 1639
# Episode 1639 | Avg Reward: 72.6 | Avg Error: 0.4032m | Path Len: 31, Path Step Reached: 30, Max step reached
# Update performed at episode 1659
# Episode 1659 | Avg Reward: 63.8 | Avg Error: 0.4082m | Path Len: 17, Path Step Reached: 16, Max step reached
# Update performed at episode 1679
# Episode 1679 | Avg Reward: 74.0 | Avg Error: 0.4681m | Path Len: 25, Path Step Reached: 24, Max step reached
# Update performed at episode 1699
# Episode 1699 | Avg Reward: 73.3 | Avg Error: 0.3508m | Path Len: 20, Path Step Reached: 19, Max step reached
# Update performed at episode 1719
# Episode 1719 | Avg Reward: 88.2 | Avg Error: 0.5106m | Path Len: 16, Path Step Reached: 12, Max step reached
# Update performed at episode 1739
# Episode 1739 | Avg Reward: 58.5 | Avg Error: 0.7767m | Path Len: 18, Path Step Reached: 17, Too Far from Path
# Update performed at episode 1759
# Episode 1759 | Avg Reward: 111.7 | Avg Error: 0.5794m | Path Len: 15, Path Step Reached: 11, Max step reached
# Update performed at episode 1779
# Episode 1779 | Avg Reward: 83.2 | Avg Error: 0.3943m | Path Len: 18, Path Step Reached: 17, Max step reached
# Update performed at episode 1799
# Episode 1799 | Avg Reward: 67.3 | Avg Error: 0.8375m | Path Len: 12, Path Step Reached: 9, Max step reached
# Update performed at episode 1819
# Episode 1819 | Avg Reward: 64.0 | Avg Error: 0.3792m | Path Len: 22, Path Step Reached: 21, Max step reached
# Update performed at episode 1839
# Episode 1839 | Avg Reward: 95.9 | Avg Error: 0.7591m | Path Len: 18, Path Step Reached: 17, Max step reached
# Update performed at episode 1859
# Episode 1859 | Avg Reward: 80.3 | Avg Error: 0.3298m | Path Len: 23, Path Step Reached: 22, Max step reached
# Update performed at episode 1879
# Episode 1879 | Avg Reward: 59.2 | Avg Error: 0.4755m | Path Len: 19, Path Step Reached: 18, Max step reached
# Update performed at episode 1899
# Episode 1899 | Avg Reward: 59.1 | Avg Error: 0.7792m | Path Len: 11, Path Step Reached: 10, Max step reached
# Update performed at episode 1919
# Episode 1919 | Avg Reward: 67.5 | Avg Error: 0.6058m | Path Len: 18, Path Step Reached: 17, Max step reached
# Update performed at episode 1939
# Episode 1939 | Avg Reward: 72.3 | Avg Error: 0.4638m | Path Len: 16, Path Step Reached: 15, Max step reached
# Update performed at episode 1959
# Episode 1959 | Avg Reward: 95.3 | Avg Error: 0.1985m | Path Len: 15, Path Step Reached: 14, Goal Reached
# Update performed at episode 1979
# Episode 1979 | Avg Reward: 114.3 | Avg Error: 0.3142m | Path Len: 28, Path Step Reached: 26, Max step reached
# Update performed at episode 1999
# Episode 1999 | Avg Reward: 105.5 | Avg Error: 0.6543m | Path Len: 15, Path Step Reached: 14, Max step reached
# Training Complete.

# %% [markdown]
# ### Cell 7: Visualization & Save
# Plot the learning curve to verify convergence.

# %%
import os
import torch
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime

# --- 1. SETUP DIRECTORY STRUCTURE ---
current_time = datetime.now().strftime("%Y%m%d_%H%M%S")
run_id = f"run_{current_time}"

if SAVE_ON_DRIVE:
    base_output_path = os.path.join(drive_path, "experiments")
else:
    base_output_path = "experiments"

output_dir = os.path.join(base_output_path, run_id)
os.makedirs(output_dir, exist_ok=True)

print(f"Results will be saved to: {output_dir}")

# --- 2. PLOTTING AND SAVING FIGURES ---
# We create a figure with 2 subplots (1 row, 2 columns)
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))

# Process histories to ensure they are plottable (handle tensors)
clean_rewards = [r.detach().cpu().item() if torch.is_tensor(r) else r for r in reward_history]
clean_losses = [l.detach().cpu().item() if torch.is_tensor(l) else l for l in loss_history]

# Plot 1: Total Reward
ax1.plot(clean_rewards, color='blue')
ax1.set_title("Training Reward")
ax1.set_xlabel("Episode")
ax1.set_ylabel("Total Reward")
ax1.grid(True)

# Plot 2: Training Loss
# Note: Ensure you are appending your loss values to a list named 'loss_history' during training
ax2.plot(clean_losses, color='red')
ax2.set_title("Training Loss")
ax2.set_xlabel("Episode")
ax2.set_ylabel("Loss")
ax2.grid(True)

plt.suptitle(f"REINFORCE Training Metrics - {run_id}")
plt.tight_layout() # Adjust spacing so titles don't overlap

# Save the combined plot
plot_filename = "training_metrics_plot.png"
plt.savefig(os.path.join(output_dir, plot_filename))
plt.show()

# --- 3. SAVING MODEL AND DATA ---
model_filename = "policy_model.pth"
torch.save(policy.state_dict(), os.path.join(output_dir, model_filename))

# Save both histories for future analysis
np.save(os.path.join(output_dir, "reward_history.npy"), np.array(clean_rewards))
np.save(os.path.join(output_dir, "loss_history.npy"), np.array(clean_losses))

print("-" * 30)
print(f"Execution complete.")
print(f"Directory: {output_dir}")
print(f"Saved: {model_filename}, {plot_filename}, histories (.npy)")
print("-" * 30)
# Out:
# Results will be saved to: /content/drive/MyDrive/final_assignment/models_saved/experiments/run_20260103_175743
# ------------------------------
# Execution complete.
# Directory: /content/drive/MyDrive/final_assignment/models_saved/experiments/run_20260103_175743
# Saved: policy_model.pth, training_metrics_plot.png, histories (.npy)
# ------------------------------

# %% [markdown]
# ### Cell 8: ⚠ Delete the train directory ( only for bed results )

# %%
import shutil

# --- DELETE CURRENT EXPERIMENT DIRECTORY ---
# Ask for confirmation to prevent accidental deletion
confirm = input(f"Do you want to delete the directory '{run_id}'? (y/n): ")

if confirm.lower() == 'y':
    try:
        # shutil.rmtree deletes a directory and all its contents
        shutil.rmtree(output_dir)
        print(f"Successfully deleted: {output_dir}")
    except OSError as e:
        print(f"Error: {e.strerror}. Could not delete the directory.")
else:
    print("Deletion cancelled. Experiment results preserved.")
