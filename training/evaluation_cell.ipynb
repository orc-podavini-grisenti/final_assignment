# %% [markdown]
# ### Evalutaion Cell

# %%
from evaluation.navigation_evaluation import evaluate_single_nav_model

model_path = 'path where the trained model has been stored'
model_alias = 'a name for identify the model'
# NB the render = True ti permette di vedere tutti i 50 episodi runnati dall'evaluation. Molto utile per
#    capire come si comporta il modello ( molto piu utile che solo leggere i valori ritornati dall'evaluation )

evaluate_single_nav_model(model_path, model_alias, render = True)
